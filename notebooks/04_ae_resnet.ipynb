# %% [markdown]
# # 04_AE_ResNet
# ### Research Question: Does attention-gated feature learning improve classification and calibration performance?
# Trains the proposed **AE-ResNet** architecture, saves optimal weights to `models/ae_resnet_baseline.pth`, and outputs **Figure 3: Training Curves** and **Figure 5: ROC Curves**.

# %%
print('Training proposed AE-ResNet...')
