# %% [markdown]
# # 03_Baseline_Training
# ### Research Question: How strong are standard, control deep classifiers on retinal OCT scans?
# Trains control backbones (**ResNet-50, DenseNet-121, EfficientNet-B0**) on the OCTDL dataset, producing baseline training curves and **Figure 4: Baseline Confusion Matrices**.

# %%
import torch
import torchvision.models as models
print('Training baselines...')
