# %% [markdown]
# # 05_Ablation
# ### Research Question: Which components of the proposed network drive the diagnostic improvement?
# Isolates the step-wise impact of weighted loss, weighted sampling, and channel/spatial attention streams, producing **Table 3: Ablation Study**.

# %%
print('Running ablation configurations...')
