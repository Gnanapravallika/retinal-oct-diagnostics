# %% [markdown]
# # 02_Preprocessing
# ### Research Question: Does preprocessing enhance tissue contrast without distorting anatomy?
# This notebook tests the edge-preserving Bilateral filter, CLAHE contrast scaling, and Min-Max normalization, producing **Figure 1: Preprocessing Visual Comparison**.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Visual comparison routine of original vs processed
print('Testing image standardizer filters...')
