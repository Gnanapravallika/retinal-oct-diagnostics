# %% [markdown]
# # 07_External_Validation
# ### Research Question: Does the model maintain generalization and explanation stability under scanner domain shift?
# Evaluates trained backbones on the external **OCTID cohort** under un-normalized vs normalized profiles, producing **Table 5: External Generalization** and **Figure 9: Saliency Drift Visualizations**.

# %%
print('Evaluating cross-device domain generalization on OCTID...')
