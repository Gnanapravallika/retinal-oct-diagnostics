# %% [markdown]
# # 09_Paper_Assets
# ### Final Phase: Compilation of all publication-ready figures and tables.
# Gathers all saved tables and figures, formatting them into LaTeX-ready scripts and ZIP archives.

# %%
print('Packaging figures and tables for final LaTeX paper import...')
