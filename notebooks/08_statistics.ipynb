# %% [markdown]
# # 08_Statistics
# ### Research Question: Are the observed diagnostic improvements statistically consistent?
# Runs the models over 5 random seeds to compute Mean, SD, 95% Confidence Intervals, and Wilcoxon significance tests, producing **Table 7: Statistical Summary**.

# %%
print('Computing multi-seed standard deviation and Wilcoxon significance tests...')
