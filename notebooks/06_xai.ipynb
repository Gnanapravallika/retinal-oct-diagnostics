# %% [markdown]
# # 06_XAI
# ### Research Question: Are the deep visual explanations mathematically faithful to the model's calculations?
# Extracts LayerCAM attributions, runs progressive deletion and insertion perturbation tests, and computes AOPC, producing **Figure 6: LayerCAM Visualizations** and **Figures 7 & 8: Deletion/Insertion Curves**.

# %%
print('Extracting visual attributions and running AOPC perturbation audits...')
